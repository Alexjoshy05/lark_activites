# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Telco-Customer-Churn.xlsx - Telco-Customer-Churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data1=pd.DataFrame(data,columns=['gender','Churn'])

# %%
data1
# Out:
#       gender Churn
# 0     Female    No
# 1       Male    No
# 2       Male   Yes
# 3       Male    No
# 4     Female   Yes
# ...      ...   ...
# 7038    Male    No
# 7039  Female    No
# 7040  Female    No
# 7041    Male   Yes
# 7042    Male    No
#
# [7043 rows x 2 columns]

# %% [markdown]
# # 1. Compare churn count with respect to gender

# %%
plt.figure(figsize=(5,6))
data2=sns.countplot(x='gender',hue='Churn',data=data1)
plt.grid()

# %% [markdown]
# # 2. Find out how many female senior citizens there in the dataset

# %%
data3=data[(data['gender']=='Female') & (data['SeniorCitizen']==1)]

# %%
data3
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %% [markdown]
# # 2. Find out how many female senior citizens there in the dataset

# %%
plt.figure(figsize=(4,6))
sns.countplot(x=data3['gender'])
plt.title('Female senior citizens ',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Female senior citizens ')

# %% [markdown]
# # 3. Compare 'tenure' with 'Total Charges'

# %%
plt.figure(figsize=(10,8))
plt.scatter(data['tenure'],data['TotalCharges'],s=10,c='red',marker='^')
plt.title('Tenure v/s Total charges',fontsize=15)
plt.xlabel('Tenure',fontsize=12)
plt.ylabel('Total Charges',fontsize=12)
# Out:
# Text(0, 0.5, 'Total Charges')

# %% [markdown]
# # 4. Find out which contract is preferred by the senior citizen.

# %%
data4=data[(data['SeniorCitizen']==1)]

# %%
data4
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 30    3841-NFECX  Female              1     Yes         No      71
# 31    4929-XIHVW    Male              1     Yes         No       2
# 34    3413-BMNZE    Male              1      No         No       1
# 50    8012-SOUDQ  Female              1      No         No      43
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7032  6894-LFHLY    Male              1      No         No       1
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
plt.figure(figsize=(6,8))
sns.countplot(x=data4['Contract'])
plt.grid()
plt.title('Contract Preferred by Senior citizen',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Contract Preferred by Senior citizen')

# %% [markdown]
# # 5. Comment on your finds on Payment Method?

# %%
plt.figure(figsize=(10,10))
plt.title('Payment Method',fontsize=15,fontweight='bold')
sns.countplot(x=data['PaymentMethod'])
plt.grid()

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='PaymentMethod',hue='gender',data=data)
plt.title('Payment menthod Genderwise',fontsize=15,fontweight='bold')
plt.grid()

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=data4['PaymentMethod'])
plt.title('Payment menthod Senior citizen',fontsize=15,fontweight='bold')
plt.grid()

# %%
data5=data[(data['SeniorCitizen']==0)]

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=data5['PaymentMethod'])
plt.title('Payment Menthod of Citizen',fontsize=15,fontweight='bold')
plt.grid()

# %%
#observations
# 1. Most prefred payment menthod is 'Electronic check' whether we classify by gender/senior citizen it is same.
# 2. Only bank transfer payment menthod is used by female more than men
# 3. Senior citizen is largely depend on Electronic check payment menthod where Citizen is not that much depend on electronic check
#     payment menthod
